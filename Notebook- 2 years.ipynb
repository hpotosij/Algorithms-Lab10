# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5eb8ea954468e746308afbf8')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:11|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-05-07</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-05-08</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>24</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-2.533%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-5.021%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.737%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.52</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.29</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.05</td>
#     </tr>
#     <tr>
# ...
